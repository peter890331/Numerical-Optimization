# %% [markdown]
# # Numerical Optimization Assignment 1
# ## Introduction
# In this assignment, we expect you to be familiar with optimization library, the numerical calculation package **SciPy**. We are using the Rosenbrock function as the benchmark of our optimization algorithms. Rosenbrock is a simple fourth-order function that has the minimal point at [1,1]. (https://en.wikipedia.org/wiki/Rosenbrock_function) We provide a visualization function which draws the contour.
# ## Task
# 1. Please finish the TODO part, which you're going to read the document of SciPy and learn how to minimize function.
#     You may refer to the information in the following link: https://docs.scipy.org/doc/scipy/reference/optimize.html
# 2. Please apply SciPy library of the optimization algorithm of _BFGS_, _Conjugate Gradient_, _Modified Newton's method with conjugate gradient_ with the initilal guess [-2,2].
# 3. Gradient descent is not included in SciPy package, please implement "Gradient descent with optimal step length".
#     Please refer to page 11 of unit 2.
# 4. Newton's method is not included in SciPy package, please implement "Pure Newton's method".
#     Please refer to page 18 of unit 2.
# 5. Write a concise report about:
#     * Comparing the behavior of these algorithms, include the visualized plot, number of iterarions, step length etc.
#     * How do you implement the Gradient descent and Newton's method algorithm.
#     * Note: Write your report in the LAST cell of this notebook in Markdown Style. If you are new to Markdown, please check this tutorial link: https://www.markdowntutorial.com/, and Markdown syntax: https://www.markdownguide.org/basic-syntax/
# 6. Rename this notebook file by adding your student ID and upload it to eeclass platform. (ex. hw1_110xxxxxx.ipynb)
# 7. Please make sure that clicking "Restart & Run All" will give the result you want to show.

# %% [markdown]
# ## Import packages and visualization
# If you imported extra packages, please mention in your report.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize, rosen, rosen_der, rosen_hess
# rosen, rosen_der, rosen_hess is the built-in Rosenborck function and its first and second order derivative
from numpy import linalg as la
from scipy import optimize

# %%
def visualize(x_iter):
    x0_iter = np.array([i[0] for i in x_iter])
    x1_iter = np.array([i[1] for i in x_iter])
    x = np.linspace(-2,2,1000)
    y = np.linspace(-1,3,1000)
    X, Y = np.meshgrid(x, y)
    Z = rosen([X,Y])

    anglesx = x0_iter[1:] - x0_iter[:-1]
    anglesy = x1_iter[1:] - x1_iter[:-1]

    # %matplotlib inline
    fig, ax = plt.subplots()
    CS = ax.contour(X, Y, Z, 50, cmap = 'jet')
    ax.set_title('Contour')
    for i in x_iter:
        ax.scatter(i[0],i[1],color = 'r', marker = '.')

    for i in range(len(x_iter)-1):
        ax.quiver(x_iter[i][0], x_iter[i][1], anglesx[i], anglesy[i], scale_units = 'xy', angles = 'xy', scale = 1, color = 'r', alpha = .3)

    plt.show()

# %% [markdown]
# ## BFGS (10%)

# %%
x0 = np.array([-2,2])
x_iter = list() # a list which contains new x for each step of iteration
# TODO (HINT: Hessian will NOT be used in this optimize function)
'''def rosen(x):
  #The Rosenbrock function
  return 100.0*(x[1]-x[0]**2.0)**2.0 + (1-x[0])**2.0

def rosen_der(x):
  der = np.zeros_like(x)
  der[0] = -400*x[0]*(x[1]-x[0]**2) - 2*(1-x[0])
  der[1] = 200*(x[1]-x[0]**2)
  return der'''

res = minimize(rosen, x0, method='BFGS', jac=rosen_der, options={'disp': True,'return_all': True})

for i in range(len(res.allvecs)):
  x_iter.append(res.allvecs[i])

visualize(x_iter)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 42
#          Gradient evaluations: 42

# %% [markdown]
# ## Conjugate Gradient (10%)

# %%
x0 = np.array([-2,2])
x_iter = list()
# TODO (HINT: Hessian will NOT be used in this optimize function)
res = minimize(rosen, x0, method= 'CG', jac=rosen_der, options={'disp': True,'return_all': True})

for i in range(len(res.allvecs)):
  x_iter.append(res.allvecs[i])

visualize(x_iter)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 34
#          Function evaluations: 78
#          Gradient evaluations: 78

# %% [markdown]
# ## Modified Newton's method with conjugate gradiet (Newton-CG) (10%)

# %%
x0 = np.array([-2,2])
x_iter = list()
## TODO (HINT:You will need to feed in rosen_hess in this optimize function)
'''def rosen_hess(x):
  x = np.asarray(x)
  H = np.diag(-400*x[:-1],1) - np.diag(400*x[:-1],-1)
  diagonal = np.zeros_like(x)
  diagonal[0] = 1200*x[0]**2-400*x[1]+2
  diagonal[-1] = 200
  diagonal[1:-1] = 202 + 1200*x[1:-1]**2 - 400*x[2:]
  H = H + np.diag(diagonal)
  return H'''

res = minimize(rosen, x0, method='Newton-CG',
               jac=rosen_der, hess=rosen_hess,
               options={'disp': True,'return_all': True})

for i in range(len(res.allvecs)):
  x_iter.append(res.allvecs[i])

visualize(x_iter)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 275
#          Function evaluations: 296
#          Gradient evaluations: 296
#          Hessian evaluations: 275

# %% [markdown]
# ## Gradient Descent with optimal step length (20%)

# %%
def Gradient_Descent(Grad, x, epsilon=0.00001, nMax = 10000 ):
    # TODO
    # Input arguments:
        # Grad: the derivative of the objective function
        # x: initial guess
        # epsilon: the tolerence of error during optimization, if error is less than epsilon we consider it as convergence
        # nMax: maxinum number of iteration, you can manually modify this constatnt if the default value is not enough
    # Output arguments:
        # x_iter: a list which contains new x for each step of iteration
        # iter_count: an integer, the number of iteration the algorithm taken to convergence
    
    x_iter=list()
    step_length=list()
    iter_count=1
    v=x
    x_iter.append(v)
    def f(t):
      return rosen(v-t*Grad(v))
      
    while la.norm(Grad(v)) > epsilon and iter_count<nMax:
      min=optimize.fmin(f,0.001)
      v = v - min*Grad(v)
      x_iter.append(v)
      iter_count+=1

    return x_iter, iter_count

# %%
x0 = np.array([-2,2])
x_iter, iter_count = Gradient_Descent(rosen_der,x0)
print('Iteration Count: %d\n' % iter_count)
print('At ', x_iter[-1], ', the function value is ', rosen(x_iter[-1]), sep='')
visualize(x_iter)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000047
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000046
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000045
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000044
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000037
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000036
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
# ...
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000017
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Optimization terminated successfully.
#          Current function value: 0.000016
#          Iterations: 1
#          Function evaluations: 2
# Iteration Count: 10000
#
# At [0.99595692 0.99191398], the function value is 1.6372767852959267e-05

# %% [markdown]
# ## Pure Newton's Method (20%)

# %%
def Newton(Grad, Grad2, x, epsilon=0.00001, nMax = 10000 ):
    # TODO
    # Input arguments:
        # Grad: the derivative of the objective function
        # Grad2: the second derivative of the objective function
        # x: initial guess
        # epsilon: the tolerence of error during optimization, if error is less than epsilon we consider it as convergence
        # nMax: maxinum number of iteration, you can manually modify this constatnt if the default value is not enough
    # Output arguments: (same as above)
    # Hint: Use numpy.linalg to compute the inverse of a matrix

    x_iter=list()
    iter_count=1
    v=x
    x_iter.append(v)
    while la.norm(Grad(v)) > epsilon and iter_count < nMax :
      h_inv = la.inv(Grad2(v))
      v = v - h_inv.dot(Grad(v))
      x_iter.append(v)
      iter_count+=1

    return x_iter, iter_count

# %%
x0 = np.array([-2,2])
x_iter, iter_count = Newton(rosen_der,rosen_hess,x0)
print('Iteration Count: %d\n' % iter_count)
print('At ', x_iter[-1], ', the function value is ', rosen(x_iter[-1]), sep='')
visualize(x_iter)
# Out:
# Iteration Count: 6
#
# At [1. 1.], the function value is 1.8096246201576487e-19

# %% [markdown]
# ## Report (30%)

# %% [markdown]
# ####BFGS
# 　　Optimization terminated successfully.
# 　　Current function value: 0.000000
# 　　Iterations: 35
# 　　Function evaluations: 42
# 　　Gradient evaluations: 42
# ![image.png](data:image/png;base64,...)
#
# ####Conjugate Gradient
# 　　Optimization terminated successfully.
# 　　Current function value: 0.000000
# 　　Iterations: 34
# 　　Function evaluations: 78
# 　　Gradient evaluations: 78
# ![image.png](data:image/png;base64,...)
#
# ####Modified Newton's method with conjugate gradiet (Newton-CG)
# 　　Optimization terminated successfully.
# 　　Current function value: 0.000000
# 　　Iterations: 275
# 　　Function evaluations: 296
# 　　Gradient evaluations: 296
# 　　Hessian evaluations: 275
# ![image.png](data:image/png;base64,...)
#
# ####Gradient Descent with optimal step length
# 　　.
# 　　.
# 　　.
# 　　Optimization terminated successfully.
# 　　Current function value: 0.000016
# 　　Iterations: 1
# 　　Function evaluations: 2
# 　　Iteration Count: 10000
#
# 　　At [0.99595692 0.99191398], the function value is 1.6372767852959267e-05
# ![image.png](data:image/png;base64,...)
#
# ####Pure Newton's Method
# 　　Iteration Count: 6
# 　　At [1. 1.], the function value is 1.8096246201576487e-19
# #####此為最佳解法，只要六步就可找到目標，每步走的幅度大但非常快速
# ![image.png](data:image/png;base64,...)
#
# >Gradient descent with optimal step
# >>是根據講義ppt上的公式，找到optimal step，藉由定義f(t)，代入原本的Rosen function，即可獲得最小值t。
#
# >Pure Newton's Method
# >>先根據Newton's Method分別算出一次和二次微分，再將其相除（使用.dot做矩陣相乘），就會得(2,1)的矩陣，再做相減即可得到新的x的座標
#
# 新增的兩種函示庫，一個是為了做較簡單的線性代數運算，另一個是用來直接找到最小值
